# %% [markdown]
# <font color='DarkBlue' size=+2><b>Комментарий ревьюера</b></font><br>
# <font color='DarkBlue'>Привет, Сергей! <br>Меня зовут Олег Мазуренко, и я буду проверять этот проект. Спасибо за проделанную работу! <br>Ко мне можно обращаться на «ты». Как мне обращаться, напиши.</font><br>
# <font color='DarkBlue'>Я буду использовать различные цвета, чтобы было удобнее воспринимать мои комментарии:</font><br>
# <font color='DarkBlue'>Синий текст &mdash; просто текст комментария.</font><br>
# <font color='DarkGreen'>👌 Зеленый текст &mdash; все отлично.</font><br>
# <font color='DarkMagenta'>👉 Фиолетовый текст &mdash; сделано все правильно, однако есть рекомендации, на что стоит обратить внимание. Реализованные рекомендации позволят нам наработать опыт решения задачи разными способами или посмотреть на задачу под иным углом.</font><br>
# <font color='Red'>🛠 Красный текст &mdash; есть недочеты, они иногда бывают. </font><br><font color='DarkBlue'>Любая ошибка это возможность посмотреть на задачу с другой стороны и освоить новые знания, по этому не надо расстраиваться, если они есть.</font><br>
# <font color='DarkBlue'>Пожалуйста, не удаляй мои комментарии в случае возврата работы, так будет проще разобраться, какие были недочеты и сразу увидеть исправленное. <br>
# Ответы на мои комментарии лучше тоже помечать.
# Например: </font><font color='Blue'><b>Комментарий студента</b></font><br>
# <font color='DarkBlue'><b>Теперь посмотрим, что у нас получилось!</b></font>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта-и-общий-обзор-данных" data-toc-modified-id="Описание-проекта-и-общий-обзор-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта и общий обзор данных</a></span><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Загрузка-и-общий-обзор-данных" data-toc-modified-id="Загрузка-и-общий-обзор-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Загрузка и общий обзор данных</a></span></li></ul></li><li><span><a href="#Предобработка" data-toc-modified-id="Предобработка-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка</a></span></li><li><span><a href="#Исследовательский-анализ" data-toc-modified-id="Исследовательский-анализ-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ</a></span><ul class="toc-item"><li><span><a href="#Данные-о-городах-пользователей-и-типах-подписки" data-toc-modified-id="Данные-о-городах-пользователей-и-типах-подписки-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Данные о городах пользователей и типах подписки</a></span></li><li><span><a href="#Данные-о-возрасте-пользователей" data-toc-modified-id="Данные-о-возрасте-пользователей-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Данные о возрасте пользователей</a></span></li><li><span><a href="#Дистаниция-и-длительность-поездок" data-toc-modified-id="Дистаниция-и-длительность-поездок-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Дистаниция и длительность поездок</a></span></li><li><span><a href="#Выводы." data-toc-modified-id="Выводы.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Выводы.</a></span></li></ul></li><li><span><a href="#Объединение-данных-и-оценка-параметров-по-типам-подписки" data-toc-modified-id="Объединение-данных-и-оценка-параметров-по-типам-подписки-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Объединение данных и оценка параметров по типам подписки</a></span><ul class="toc-item"><li><span><a href="#Объединение-датафреймов" data-toc-modified-id="Объединение-датафреймов-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Объединение датафреймов</a></span></li><li><span><a href="#Разделение-датафреймов-по-типу-подписки" data-toc-modified-id="Разделение-датафреймов-по-типу-подписки-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Разделение датафреймов по типу подписки</a></span></li><li><span><a href="#Визуализация-различий-групп-пользователей-по-типам-подписки" data-toc-modified-id="Визуализация-различий-групп-пользователей-по-типам-подписки-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Визуализация различий групп пользователей по типам подписки</a></span></li><li><span><a href="#Выводы." data-toc-modified-id="Выводы.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Выводы.</a></span></li></ul></li><li><span><a href="#Подсчёт-выручки" data-toc-modified-id="Подсчёт-выручки-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Подсчёт выручки</a></span><ul class="toc-item"><li><span><a href="#Создание-датафрейма-с-агрегированными-данными" data-toc-modified-id="Создание-датафрейма-с-агрегированными-данными-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Создание датафрейма с агрегированными данными</a></span></li><li><span><a href="#Добавление-помесячной-выручки" data-toc-modified-id="Добавление-помесячной-выручки-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Добавление помесячной выручки</a></span></li><li><span><a href="#Выводы." data-toc-modified-id="Выводы.-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Выводы.</a></span></li></ul></li><li><span><a href="#Проверка-гипотез" data-toc-modified-id="Проверка-гипотез-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Проверка гипотез</a></span><ul class="toc-item"><li><span><a href="#Проверка-гипотезы-тратят-ли-пользователи-с-подпиской-больше-времени-на-поездки?" data-toc-modified-id="Проверка-гипотезы-тратят-ли-пользователи-с-подпиской-больше-времени-на-поездки?-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Проверка гипотезы тратят ли пользователи с подпиской больше времени на поездки?</a></span></li><li><span><a href="#Проверка-гипотезы-что-среднее-расстояние,-которое-проезжают-пользователи-с-подпиской-за-одну-поездку,-не-превышает-3130-метров" data-toc-modified-id="Проверка-гипотезы-что-среднее-расстояние,-которое-проезжают-пользователи-с-подпиской-за-одну-поездку,-не-превышает-3130-метров-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Проверка гипотезы что среднее расстояние, которое проезжают пользователи с подпиской за одну поездку, не превышает 3130 метров</a></span></li><li><span><a href="#Проверка-гипотезы-что-помесячная-выручка-от-пользователей-с-подпиской-по-месяцам-выше,-чем-выручка-от-пользователей-без-подписки." data-toc-modified-id="Проверка-гипотезы-что-помесячная-выручка-от-пользователей-с-подпиской-по-месяцам-выше,-чем-выручка-от-пользователей-без-подписки.-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Проверка гипотезы что помесячная выручка от пользователей с подпиской по месяцам выше, чем выручка от пользователей без подписки.</a></span></li><li><span><a href="#Проверка-гипотезы-об-уменьшении-количества-обращений-в-тех.-поддержку" data-toc-modified-id="Проверка-гипотезы-об-уменьшении-количества-обращений-в-тех.-поддержку-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Проверка гипотезы об уменьшении количества обращений в тех. поддержку</a></span></li><li><span><a href="#Выводы." data-toc-modified-id="Выводы.-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Выводы.</a></span></li></ul></li><li><span><a href="#Распределения" data-toc-modified-id="Распределения-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Распределения</a></span><ul class="toc-item"><li><span><a href="#Акция-с-раздачей-промокодов." data-toc-modified-id="Акция-с-раздачей-промокодов.-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Акция с раздачей промокодов.</a></span></li><li><span><a href="#Рассылка-push-уведомлений" data-toc-modified-id="Рассылка-push-уведомлений-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Рассылка push-уведомлений</a></span></li></ul></li><li><span><a href="#Общие-выводы" data-toc-modified-id="Общие-выводы-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Общие выводы</a></span></li></ul></div>

# %% [markdown]
# </font><font color='Blue'><b>Комментарий студента</b></font><br>
# Привет, Олег! Ко мне тоже можно на "ты". Спасибо за комментарии, это мой "первый блин" подготовки проекта
# вне платформы: после мастерской решил попробовать делать проекты в Google Colab, поэтому не всё пошло гладко)
# Кстати, хочу спросить твоего совета: как лучше - загружать на платформу Colab файлы с проектами или Jupyter-тетрадки
# выполненные локально?

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Привет! Те и другие имеют один формат, главное, что бы после загрузки на Сервер перезапустить тетрадку и если нет ошибки, то можно отправлять. Только надо иметь ввиду, что в Google Colab совсем другое окружение и исполняемые там тетрадки могут не запуститься на Сервере.</font>

# %% [markdown]
# # GoFast_самокаты

# %% [markdown]
# ## Описание проекта и общий обзор данных

# %% [markdown]
# ### Описание проекта

# %% [markdown]
# __Цель проекта:__ Провести анализ имеющихся данных для сравнения поведения пользователей с разными типами подписки и проверить некоторые гипотезы, которые могут помочь бизнесу вырасти.
#
# __Данные:__ В проекте используются данные о некоторых пользователях популярного сервиса аренды самокатов __GoFast__ из нескольких городов, а также об их поездках в течение 2021 года.
#
# Чтобы совершать поездки по городу, пользователи сервиса GoFast пользуются мобильным приложением. Сервисом можно пользоваться:
#
# - без подписки
#
# абонентская плата отсутствует;
#
# стоимость одной минуты поездки — 8 рублей;
#
# стоимость старта (начала поездки) — 50 рублей;
#
# - с подпиской Ultra
#
# абонентская плата — 199 рублей в месяц;
#
# стоимость одной минуты поездки — 6 рублей;
#
# стоимость старта — бесплатно.
#
# __Задачи:__
# 1. Найти суммарное расстояние, количество поездок, суммарное время и помесячную выручку для каждого пользователя за каждый месяц;
# 2. Проверить некоторые гипотезы, которые помогут выяснить важные для дальнейшего развития бизнеса моменты;
# 3. Визуализировать разницу в поведении пользователей с подпиской и без неё.

# %% [markdown]
# ### Описание данных

# %% [markdown]
# Есть три файла с данными, представляющими информацию о пользователях, их поездках и подписках.
#
# __Пользователи__ — `users_go.csv`
#
# `user_id` -	уникальный идентификатор пользователя
#
# `name` - имя пользователя
#
# `age` -	возраст
#
# `city` - город
#
# `subscription_type` - тип подписки (free, ultra)
#
# _____
#
# __Поездки__ — `rides_go.csv`
#
# `user_id` -	уникальный идентификатор пользователя
#
# `distance` -	расстояние, которое пользователь проехал в текущей сессии (в метрах)
#
# `duration` -	продолжительность сессии (в минутах) — время с того момента, как пользователь нажал кнопку «Начать поездку» до момента, как он нажал кнопку «Завершить поездку»
#
# `date` -	дата совершения поездки
#
# -----
#
# __Подписки__ — `subscriptions_go.csv`
#
# `subscription_type` - тип подписки
#
# `minute_price` - стоимость одной минуты поездки по данной подписке
#
# `start_ride_price` - стоимость начала поездки
#
# `subscription_fee` - стоимость ежемесячного платежа

# %% [markdown]
# ____

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 00</b></font><br>
# <font color='DarkGreen'>👌 Хорошо сделано описание к проекту. 👍</font>

# %% [markdown]
# ### Загрузка и общий обзор данных

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %config InlineBackend.figure_format = 'retina'
matplotlib.style.use('ggplot')
plt.rc('figure', figsize=(15, 6))

# %%
users = pd.read_csv('https://code.s3.yandex.net/datasets/users_go.csv')
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1565 entries, 0 to 1564
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            1565 non-null   int64
#  1   name               1565 non-null   object
#  2   age                1565 non-null   int64
#  3   city               1565 non-null   object
#  4   subscription_type  1565 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 61.3+ KB

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 00</b></font><br>
# <font color='DarkGreen'>👌 Очень хорошо! Загрузка датасета непосредственно с сервера и все равно от куда запускается тетрадка. 👍</font>

# %%
users.head()
# Out:
#    user_id        name  age            city subscription_type
# 0        1        Кира   22          Тюмень             ultra
# 1        2   Станислав   31            Омск             ultra
# 2        3     Алексей   20          Москва             ultra
# 3        4  Константин   26  Ростов-на-Дону             ultra
# 4        5       Адель   28            Омск             ultra

# %%
rides = pd.read_csv('https://code.s3.yandex.net/datasets/rides_go.csv')
rides.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18068 entries, 0 to 18067
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   18068 non-null  int64
#  1   distance  18068 non-null  float64
#  2   duration  18068 non-null  float64
#  3   date      18068 non-null  object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 564.8+ KB

# %%
rides.head()
# Out:
#    user_id     distance   duration        date
# 0        1  4409.919140  25.599769  2021-01-01
# 1        1  2617.592153  15.816871  2021-01-18
# 2        1   754.159807   6.232113  2021-04-20
# 3        1  2694.783254  18.511000  2021-08-11
# 4        1  4028.687306  26.265803  2021-08-28

# %%
subs = pd.read_csv('https://code.s3.yandex.net/datasets/subscriptions_go.csv')
subs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   subscription_type  2 non-null      object
#  1   minute_price       2 non-null      int64
#  2   start_ride_price   2 non-null      int64
#  3   subscription_fee   2 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 192.0+ bytes

# %%
subs.head()
# Out:
#   subscription_type  minute_price  start_ride_price  subscription_fee
# 0              free             8                50                 0
# 1             ultra             6                 0               199

# %% [markdown]
# __Итого:__ Пропусков в данных нет, что здорово облегчает дальнейшую обработку и говорит о хорошей подготовке данных. Все наборы данных соответствуют описанию. Типы данных соответствуют параметру, за исключением параметра даты, имеющего тип object.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 00</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, изучили данные для предобработки, сделали промежуточные выводы.</font>

# %% [markdown]
# ___

# %% [markdown]
# ## Предобработка

# %%
# приведение столбца `date` к типу данных pandas

rides['date'] = rides['date'].astype('datetime64[ns]')
rides.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18068 entries, 0 to 18067
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   18068 non-null  int64
#  1   distance  18068 non-null  float64
#  2   duration  18068 non-null  float64
#  3   date      18068 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1)
# memory usage: 564.8 KB

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 00</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, преобразовали колонку `['date']` в дату.</font>

# %%
# создание нового столбца с номером месяца на основе столбца `date`.

rides['month'] = rides['date'].dt.month
rides.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18068 entries, 0 to 18067
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   18068 non-null  int64
#  1   distance  18068 non-null  float64
#  2   duration  18068 non-null  float64
#  3   date      18068 non-null  datetime64[ns]
#  4   month     18068 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2)
# memory usage: 705.9 KB

# %%
# период поездок
rides['date'].agg(['min', 'max'])
# Out:
# min   2021-01-01
# max   2021-12-30
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 00</b></font><br>
# <font color='DarkMagenta'>👉 Следовало проверить за какой период данные в датасете. Если данные за несколько лет, то номера месяцев будут в разных годах одинаковыми.</font>

# %% [markdown]
# </font><font color='Blue'><b>Комментарий студента</b></font><br>
# Сделано.

# %%
rides.head()
# Out:
#    user_id     distance   duration       date  month
# 0        1  4409.919140  25.599769 2021-01-01      1
# 1        1  2617.592153  15.816871 2021-01-18      1
# 2        1   754.159807   6.232113 2021-04-20      4
# 3        1  2694.783254  18.511000 2021-08-11      8
# 4        1  4028.687306  26.265803 2021-08-28      8

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 00</b></font><br>
# <font color='DarkGreen'>👌 Правильно выполнено задание по созданию столбца с номером месяца.</font>

# %%
# обработка дубликатов

users = users.drop_duplicates()
users.shape # обнаружились дубликаты
# Out:
# (1534, 5)

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 00</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, удалили дубликаты в таблице пользователей.</font>

# %%
rides = rides.drop_duplicates()
rides.shape # дубликатов нет
# Out:
# (18068, 5)

# %%
subs = subs.drop_duplicates()
subs.shape # дубликатов нет
# Out:
# (2, 4)

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 00</b></font><br>
# <font color='DarkMagenta'>👉 Из анализа видно, что расстояние поездки имеет формат до шести знаков после точки, следовало округлить расстояния, примерно вот так:</font>

# %%
# Комментарий ревьюера 00
temp = rides.copy() # Создаем копию, что бы не изменять текущий датасет
display(temp['distance'].head(3))
# Округление расстояния
temp['distance'] = temp['distance'].round(2)
temp['distance'].head(3)
# Out:
# 0    4409.919140
# 1    2617.592153
# 2     754.159807
# Name: distance, dtype: float64
# 0    4409.92
# 1    2617.59
# 2     754.16
# Name: distance, dtype: float64

# %% [markdown]
# </font><font color='Blue'><b>Комментарий студента</b></font><br>
# Сделано. Но есть сомнение, делать ли тоже самое с параметром длительности? При проверке гипотез длительность поездок и так округляется до бОльшего числа.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 А я не писал ничего по поводу округления времени поездки, это делается дальше.</font>

# %%
# округление расстояния
rides_rounded = rides.copy()
display(rides_rounded['distance'].head(3))
rides_rounded['distance'] = rides_rounded['distance'].round(2)
rides_rounded['distance'].head(3)
# Out:
# 0    4409.919140
# 1    2617.592153
# 2     754.159807
# Name: distance, dtype: float64
# 0    4409.92
# 1    2617.59
# 2     754.16
# Name: distance, dtype: float64

# %%
# проверка параметра длительности поездок на аномалии
fig = plt.figure(figsize =(5, 8))
plt.boxplot(rides_rounded['duration'])
plt.title("Длительность поездок")
plt.ylabel("длительность, мин")
plt.show()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 00</b></font><br>
# <font color='DarkMagenta'>👉 Следовало проверить на аномалии колонку с длительностью поездок в таблице с информацией о поездках.</font>

# %% [markdown]
# </font><font color='Blue'><b>Комментарий студента</b></font><br>
# Сделано.

# %% [markdown]
# __Итого:__ В процессе предобработки данных выяснилось, что датасет содержит данные о поездках пользователей за 2021 год, а поездки длительностью менее 2 и более 35 минут выглядят аномальными.  Кроме того, были удалены дубликаты в данных.

# %% [markdown]
# ---

# %% [markdown]
# ## Исследовательский анализ

# %% [markdown]
# ### Данные о городах пользователей и типах подписки

# %%
# города и подписка

fig = plt.figure()

ax1 = fig.add_subplot(1, 2, 1)
d = users.city.value_counts().sort_values().tail(10)

ax1 = d.plot(kind='barh', figsize=(10, 6), color='#2C8F4B', alpha=0.5)
ax1.title.set_text('Города проживания пользователей сервиса')
ax1.set_xlabel('Количество упоминаний в данных')
ax1.set_ylabel('Города')

ax2 = fig.add_subplot(1, 2, 2)
colors = ['#A3D98B', '#F3FAB6']

ax2 = users.groupby('subscription_type').size().plot(kind='pie', autopct = '%1.1f%%', colors=colors)
ax2.title.set_text('Доли пользователей по типу подписки')
ax2.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 00</b></font><br>
# <font color='Red'>🛠 Визуализация данных графиками и диаграммами подразумевает подписи всех осей и название графика  на русском языке, при необходимости наличие меток. Это относится ко всем графикам/диаграммам проекта и является критической ошибкой.</font>

# %% [markdown]
# </font><font color='Blue'><b>Комментарий студента</b></font><br>
# Подписи подправил.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Подписи осей и название нужны для того, чтобы сделать диаграммы и графики понятными и информативными, особенно для заказчика проекта. Без них было бы сложно определить, что именно изображено на графике и какие значения соответствуют каждой оси, так как заказчик не обязан разбираться в коде. Более того, подписи осей помогают установить контекст и понять, какие переменные представлены на графике. По этому при дальнейшем комментировании результатов анализа и визуализации, становятся понятны сделанные из анализа выводы. </font>

# %%
users.city.value_counts().sort_values(ascending=False).head(8)
# Out:
# Пятигорск         219
# Екатеринбург      204
# Ростов-на-Дону    198
# Краснодар         193
# Сочи              189
# Омск              183
# Тюмень            180
# Москва            168
# Name: city, dtype: int64

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, исправили.</font>

# %% [markdown]
# __Итого:__ Больше всего пользователей сервиса проживает в Пятигорске и меньше всего - в Москве. Возможно, это особенность выборки, или сервис действительно более популярен в регионах.
#
# Пользователи с подпиской ultra составляют почти половину: 45.6%.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 00</b></font><br>
# <font color='Red'>🛠 Необходимо вывести числовые значения количества пользователей по городам. Можно вот так:</font>
# ![image.png](attachment:image.png)

# %% [markdown]
# </font><font color='Blue'><b>Комментарий студента</b></font><br>
# Сделано.

# %% [markdown]
# ### Данные о возрасте пользователей

# %%
# возраст пользователей
users['age'].plot(kind='hist', bins=30, title='Возраст пользователей', color='#2C8F4B', alpha=0.5)
plt.xlabel('Возраст, лет')
plt.ylabel('Частота упоминаний в данных')
# Out:
# Text(0, 0.5, 'Частота упоминаний в данных')

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 00</b></font><br>
# <font color='Red'>🛠 График не оформлен  необходимым образом. Подписи осей должны быть на русском языке.</font>

# %% [markdown]
# </font><font color='Blue'><b>Комментарий студента</b></font><br>
# Сделано.

# %%
users['age'].describe()
# Out:
# count    1534.000000
# mean       24.903520
# std         4.572367
# min        12.000000
# 25%        22.000000
# 50%        25.000000
# 75%        28.000000
# max        43.000000
# Name: age, dtype: float64

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 00</b></font><br>
# <font color='DarkGreen'>👌 Правильно, что для анализа возраста пользователей посмотрели сводную статистику.</font>

# %% [markdown]
# __Итого:__ Возраст пользователей варьируется от 12 до 43 лет, средний возраст - 25 лет.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 00</b></font><br>
# <font color='DarkMagenta'>👉 Следовало отметить, что среди пользователей некоторым менее 18 лет, именно с этого возраста разрешен прокат самокатов. В некоторых компаниях и регионах разрешено с 14 лет, но при письменном согласии родителей. В датасете минимальный возраст 12 лет, это явное нарушение существующих норм.</font>

# %% [markdown]
# </font><font color='Blue'><b>Комментарий студента</b></font><br>
# Отметил в промежуточных выводах.

# %% [markdown]
# ### Дистаниция и длительность поездок

# %%
# дистаниция и длительность поездок

fig = plt.figure()

ax1 = fig.add_subplot(1, 2, 1)
ax1 = rides['distance'].plot(kind='hist', bins=30, title='Дистанция поездок', color='#58B769', alpha=0.7)
ax1.set_xlabel('Дистанция, м')
plt.ylabel('Частота упоминаний в данных')

ax2 = fig.add_subplot(1, 2, 2)
ax2 = rides['duration'].plot(kind='hist', bins=30, title='Длительность поездок', color='#97D386', alpha=0.7)
ax2.set_xlabel('Длительность, мин')
plt.ylabel('Частота упоминаний в данных')
# Out:
# Text(0, 0.5, 'Частота упоминаний в данных')

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 00</b></font><br>
# <font color='Red'>🛠 Графики не оформлены  необходимым образом. Подписи осей должны быть на русском языке.</font>

# %% [markdown]
# </font><font color='Blue'><b>Комментарий студента</b></font><br>
# Сделано.

# %%
rides[['distance', 'duration']].describe()
# Out:
#            distance      duration
# count  18068.000000  18068.000000
# mean    3070.659976     17.805011
# std     1116.831209      6.091051
# min        0.855683      0.500000
# 25%     2543.226360     13.597563
# 50%     3133.609994     17.678395
# 75%     3776.222735     21.724800
# max     7211.007745     40.823963

# %% [markdown]
# __Итого:__ Средняя дистанция одной поездки - чуть больше 3000 м, максимальная - 7211 м (достаточно много для самоката). 75% поездок укладываются в 3800 м.
#
# На графике виден "провал" в районе 1500 м. По описанию, стоимость поездки не зависит от дальности. Значит, снижение количества поездок на этой дистанции связано с другими факторами, влияющими всех пользователей, как с подпиской, так и без неё. (Возможно, это среднее расстояние между остановками общественного транспорта).
#
# Средняя длительность одной поездки - менее 18 мин, минимальная - 0.5 мин (кому-то хватило 30 сек, чтобы понять, что самокаты - не его тема, или просто попался неисправный). Максимальная длительность поездки - более 40 минут. 75% поездок укладываются в 22 мин.
#
# В датасете минимальный возраст 12 лет, но это похоже на нарушение существующих норм, поскольку прокат самокатов разрешен с 18 лет, в некоторых регионах - с 14 лет.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 00</b></font><br>
# <font color='DarkGreen'>👌 Хорошо сделан анализ расстояния поездок и обращено внимание на короткие поездки и дальние поездки.</font><br>
# <font color='DarkGreen'>👌 Хорошо, сделан анализ продолжительности поездок, сформулирован промежуточный вывод, отмечена аномалия. Только при длительности поездки 0,5 минуты расстояние более 4000 метров.<br>
# Не смотря на такую низкую продолжительность поездки, эти данные удалять не рекомендуется, так как в дальнейшем производится расчет выручки, которая определяет финансовый результат Сервиса аранды самокатов. Например, пользователь без подписки оплачивает фиксированную сумму только за старт поездки. Более того, в таблице видно, что эти аномально низкие поездки имеют достаточное расстояние поездки, которое то же будет анализироваться далее. А вот данный факт аномальных значений следует отметить в итоговом выводе для дальнейшей диагностики средств контроля времени поездки.</font>
# <br><font color='DarkMagenta'>👉 При удалении данных надо всегда иметь ввиду, что удаляются полностью строки датасета, которые содержат другие данные значимые для последующего анализа.</font>

# %% [markdown]
# ### Выводы.
#
# 1. Пользователи с подпиской ultra составляют почти половину - 45.6% от всех пользователей. Возраст варьируется от 12 (что не совсем правильно, поскольку существуют возрастные ограничения для пользователей сервиса) до 43 лет, средний возраст - 25 лет.
# Больше всего пользователей сервиса проживает в Пятигорске и меньше всего - в Москве.
#
# 2. Средняя дистанция одной поездки - чуть больше 3000 м, максимальная - 7211 м (достаточно много для самоката), минимальная - менее метра. 75% поездок укладываются в 3800 м, более дальние поездки встречаются в данных реже.
#
# 3. Средняя длительность одной поездки - чуть менее 18 мин, минимальная - 0.5 мин, максимальная - более 40 минут. 75% поездок укладываются в 22 мин.
#
# 4. График распределения дистанции поездок имеет одну особенность - "провал" в районе 1500 м, а на графике распределения длительности поездок такого нет. Хотя, если количество поездок на 1500 м заметно меньше, чем количество поездок на 1000 и 2000 м, то и количество поездок соответствующей длительности должно быть меньше, чего не наблюдается на графике.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 00</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, что раздел анализа заканчиваем обобщающим выводом.</font>

# %% [markdown]
# ---

# %% [markdown]
# ## Объединение данных и оценка параметров по типам подписки

# %% [markdown]
# ### Объединение датафреймов

# %%
# объединение датафреймов users и rides
data = users.merge(rides_rounded, on='user_id', how='outer')
data.sample(5)
# Out:
#        user_id       name  age          city subscription_type  distance  \
# 13040     1178    Николай   25          Сочи              free   4515.99
# 5817       619   Кристина   29  Екатеринбург             ultra   3371.97
# 2877       307     Ясмина   19     Краснодар             ultra   3887.89
# 12430     1134   Вячеслав   26          Сочи              free   4328.27
# 15734     1372  Святослав   28     Краснодар              free   3582.32
#
#         duration       date  month
# 13040  20.316331 2021-12-23     12
# 5817   13.225648 2021-05-21      5
# 2877   23.603328 2021-03-01      3
# 12430  12.618375 2021-02-19      2
# 15734   9.411702 2021-03-31      3

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18068 entries, 0 to 18067
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            18068 non-null  int64
#  1   name               18068 non-null  object
#  2   age                18068 non-null  int64
#  3   city               18068 non-null  object
#  4   subscription_type  18068 non-null  object
#  5   distance           18068 non-null  float64
#  6   duration           18068 non-null  float64
#  7   date               18068 non-null  datetime64[ns]
#  8   month              18068 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(3)
# memory usage: 1.4+ MB

# %%
# проверка на пропуски
plt.figure()
plt.title('Оценка пропущенных значений')
colours = ['#077336', '#F0F2B3']
sns.heatmap(data.isnull(), cmap=sns.color_palette(colours), alpha=0.5)
# Out:
# <AxesSubplot:title={'center':'Оценка пропущенных значений'}>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkMagenta'>👉 А где подписи осей? Здесь и ниже?</font>

# %%
full_data = data.merge(subs, on='subscription_type', how='outer')
full_data.sample(5) #датафрейм с данными о стоимости подписки
# Out:
#        user_id       name  age            city subscription_type  distance  \
# 15140     1326    Валерия   26            Сочи              free   1905.16
# 9467       920     Степан   20            Сочи              free   2556.94
# 12324     1126  Владислав   26  Ростов-на-Дону              free    659.80
# 2737       292      Агата   25       Краснодар             ultra   2918.90
# 11306     1051     Мадина   25  Ростов-на-Дону              free   2391.92
#
#         duration       date  month  minute_price  start_ride_price  \
# 15140  12.762905 2021-05-04      5             8                50
# 9467   16.523129 2021-01-31      1             8                50
# 12324  13.328722 2021-05-17      5             8                50
# 2737   17.471860 2021-05-20      5             6                 0
# 11306  16.979810 2021-08-20      8             8                50
#
#        subscription_fee
# 15140                 0
# 9467                  0
# 12324                 0
# ...

# %%
full_data.shape
# Out:
# (18068, 12)

# %%
# проверка на пропуски
plt.figure()
plt.title('Оценка пропущенных значений')
colours = ['#077336', '#F0F2B3']
sns.heatmap(full_data.isnull(), cmap=sns.color_palette(colours), alpha=0.5)
# Out:
# <AxesSubplot:title={'center':'Оценка пропущенных значений'}>

# %% [markdown]
# __Итого:__ После объединения датасетов в объединенном датафрейме пропусков не обнаружилось.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 00</b></font><br>
# <font color='Red'>🛠 Необходимо проверить размерности датасета после объединения и проверить на пропуски.</font>

# %% [markdown]
# </font><font color='Blue'><b>Комментарий студента</b></font><br>
# Проверил.

# %% [markdown]
# ### Разделение датафреймов по типу подписки

# %%
# разделение датафреймов

data_free_sub = data[data['subscription_type'] == 'free']
data_free_sub.head()
# Out:
#       user_id   name  age  city subscription_type  distance   duration  \
# 6500      700  Айдар   22  Омск              free   2515.69  14.944286
# 6501      700  Айдар   22  Омск              free    846.93  16.234663
# 6502      700  Айдар   22  Омск              free   4004.43  20.016628
# 6503      700  Айдар   22  Омск              free   1205.91   9.782872
# 6504      700  Айдар   22  Омск              free   3047.38  17.427673
#
#            date  month
# 6500 2021-01-02      1
# 6501 2021-02-01      2
# 6502 2021-02-04      2
# 6503 2021-02-10      2
# 6504 2021-02-14      2

# %%
data_free_sub.shape
# Out:
# (11568, 9)

# %%
data_ultra_sub = data[data['subscription_type'] == 'ultra']
data_ultra_sub.head()
# Out:
#    user_id  name  age    city subscription_type  distance   duration  \
# 0        1  Кира   22  Тюмень             ultra   4409.92  25.599769
# 1        1  Кира   22  Тюмень             ultra   2617.59  15.816871
# 2        1  Кира   22  Тюмень             ultra    754.16   6.232113
# 3        1  Кира   22  Тюмень             ultra   2694.78  18.511000
# 4        1  Кира   22  Тюмень             ultra   4028.69  26.265803
#
#         date  month
# 0 2021-01-01      1
# 1 2021-01-18      1
# 2 2021-04-20      4
# 3 2021-08-11      8
# 4 2021-08-28      8

# %%
data_ultra_sub.shape
# Out:
# (6500, 9)

# %% [markdown]
# __Итого:__ Разделение датафрейма на два по типам подписки прошло без потерь данных.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 После создания двух новых датасетов следовало посмотреть их размер.</font>

# %% [markdown]
# </font><font color='Blue'><b>Комментарий студента</b></font><br>
# Размеры проверил.

# %% [markdown]
# ### Визуализация различий групп пользователей по типам подписки

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 00</b></font><br>
# <font color='Red'>🛠 Ошибка кода. К сожалению, я не могу продолжить ревью. 😢</font>
# ![image.png](attachment:image.png)

# %% [markdown]
# </font><font color='Blue'><b>Комментарий студента</b></font><br>
# Удалил неработающий на платформе код.

# %%
# доли поездок
fig = plt.figure()
colors = ['#A3D98B', '#F3FAB6']

ax = data.groupby('subscription_type').size().plot(kind='pie', autopct = '%1.1f%%', colors=colors)
ax.title.set_text('Доли поездок по типу подписки')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
# количество поездок в городах
fig = plt.figure()
colors = {'free': '#A3D98B', 'ultra': '#F3FAB6'}

ultra_sub = data.query('subscription_type == "ultra"').groupby('city').size()
free_sub = data.query('subscription_type == "free"').groupby('city').size()

df = pd.DataFrame({'ultra': ultra_sub, 'free': free_sub})
ax = df.plot.barh(color=colors)
ax.set_ylabel("Города")
ax.set_xlabel("Поездки")
ax.title.set_text("Сравнение количества поездок в городах по типу подписки")

# %% [markdown]
# __Итого:__ При сравнении поездок в разных городах заметно, что в Омске и Москве доля подписки ultra больше, чем в других городах. Хотя в целом, доля поездок без подписки составляет почти 2/3 всех поездок.

# %%
# длительность поздки и тип подписки
colors = {'free': '#A3D98B', 'ultra': '#F3FAB6'}
data.groupby('subscription_type')['duration'].plot(kind='hist', histtype='step',
                                                   linewidth=3, legend=True,bins=50, color=colors, range=(1, 40))
plt.title('Длительность поездок в зависимости от типа подписки')
plt.xlabel('Длительность')
plt.ylabel('Количество поездок');

# %% [markdown]
# </font><font color='Blue'><b>Комментарий студента</b></font><br>
# Олег, можешь подсказать, как поменять цвета легенды на графике с группировкой по типу подписки? Например, чтобы free отображалось зеленым, а ultra - желтым, в общей гамме графиков.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Задать цвета словарем:</font>

# %%
# Комментарий ревьюера
#colors = {'free': 'blue', 'ultra': 'green'}
#data.groupby('subscription_type')['duration'].plot(kind='hist', histtype='step', alpha=0.5,
                                                   #linewidth=3, legend=True,bins=50, color=colors, range=(1, 40))
#plt.title('Длительность поездок в зависимости от типа подписки')
#plt.xlabel('Длительность')
#plt.ylabel('Количество поездок');

# %% [markdown]
# </font><font color='Blue'><b>Комментарий студента</b></font><br>
# Спасибо!

# %%
# дистанция и тип подписки
colors = {'free': '#A3D98B', 'ultra': '#F3FAB6'}
data.groupby('subscription_type')['distance'].plot(kind='hist', histtype='step', color=colors,
                                                   linewidth=3,grid=True, legend=True, bins=50, range=(1, 7000))
plt.title('Дистанция поездок в зависимости от типа подписки')
plt.xlabel('Дистанция')
plt.ylabel('Количество поездок');

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо сделана визуализация и гистограммы построены на одной координатной сетке.</font>

# %% [markdown]
# __Итого:__ Сравнительные графики дистанции поездок по типам подписки показывают "провал" на дистации около 1300 м для free и ещё бОльший "провал" на дистанции около 1900 м для ultra.
#
# Есть ещё одна любопытность: на дистанции около 3150 м (приблизительная средняя дистанция для обоих типов подписки), ultra имеет "пик", в то время как у free "плоская вершина". Кроме того, имеется достаточно заметное количество "нулевых" поездок с подпиской free. Вероятно, это неудачные попытки воспользоваться самокатом (или проблемы с приложением).
#
# Сравнительные графики длительности поездок с разными тарифами выглядят более логично: в целом, поездок с free больше, чем с ultra, нет значительных "пиков" и "провалов".

# %%
# разброс расстояния и длительности поездок

fig = plt.figure(figsize=(18, 6))
fig.suptitle('Разброс растояния и длительности поездок по типам подписки', size=(15))

ax1 = fig.add_subplot(1, 5, 1)
ax1 = sns.boxplot(y=data_free_sub.distance, color='#A3D98B')
ax1.set_ylim(0, 7500)
ax1.set_xlabel('free')
ax1.set_ylabel('расстояние поездок')

ax2 = fig.add_subplot(1, 5, 2)
ax2 = sns.boxplot(y=data_ultra_sub.distance, color='#ffffc2')
ax2.set_ylim(0, 7500)
ax2.set_xlabel('ultra')
ax2.set_ylabel('')

ax3 = fig.add_subplot(1, 5, 4)
ax3 = sns.boxplot(y=data_free_sub.duration, color='#A3D98B')
ax3.set_ylim(0, 45)
ax3.set_xlabel('free')
ax3.set_ylabel('длительность поездок')

ax4 = fig.add_subplot(1, 5, 5)
ax4 = sns.boxplot(y=data_ultra_sub.duration, color='#ffffc2')
ax4.set_ylim(0, 45)
ax4.set_xlabel('ultra')
ax4.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
data_ultra_sub[['age', 'distance', 'duration']].describe()
# Out:
#                age     distance     duration
# count  6500.000000  6500.000000  6500.000000
# mean     24.892615  3115.445431    18.541985
# std       4.757208   836.895369     5.572048
# min      12.000000   244.210000     3.760353
# 25%      22.000000  2785.447500    14.524654
# 50%      25.000000  3148.640000    18.178153
# 75%      28.000000  3560.577500    21.884129
# max      38.000000  5699.770000    40.823963

# %%
data_free_sub[['age', 'distance', 'duration']].describe()
# Out:
#                 age      distance      duration
# count  11568.000000  11568.000000  11568.000000
# mean      24.893326   3045.495284     17.390909
# std        4.481100   1246.173810      6.326803
# min       12.000000      0.860000      0.500000
# 25%       22.000000   2366.560000     12.958437
# 50%       25.000000   3114.650000     17.326890
# 75%       28.000000   3905.695000     21.594071
# max       43.000000   7211.010000     34.948498

# %% [markdown]
# __Итого:__ Стандартное отклонение как дистанции, так и длительности поездок с подпиской ultra меньше, чем поездок с free.
#
# Средние значения дистанции очень близки для обоих типов подписки, при этом максимальные значения заметно различаются (самая дальняя поедка с ultra на 5699 м, с free - на 7211 м).
#
# Среднее значение длительности поездок с ultra чуть выше, чем с free. Самая длительная поезка с ultra продолжалась 40 мин, с free - 35 мин.
#
# Ещё одна любопытность: максимальный возраст пользователя с ultra - 38 лет, а с free - 43 года.

# %%
# распределение средней длительности поездок по месяцам в разных городах
datah = data.pivot_table(index='city', columns='month', values='duration', aggfunc=('mean'))
color=sns.palettes.mpl_palette('YlGn')
sns.heatmap(datah, annot=True, square=True, cmap=color, alpha=0.7)
plt.title('Средняя длительность поездок по месяцам в разных городах')
plt.xlabel('Месяц')
plt.ylabel('город')
# Out:
# Text(294.32875, 0.5, 'город')

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 График не оформлен  необходимым образом. Нет названия.</font>

# %% [markdown]
# </font><font color='Blue'><b>Комментарий студента</b></font><br>
# Название добавил.

# %% [markdown]
# __Итого:__ Забавно, но, похоже, что мороз и снег в Екатеринбурге и Тюмени любителям самокатов совершенно не помеха 😀

# %%
# "Рекордсмены" по длительности и дистанции поездок

# Топ-5 рекордсменов по дистанции с free
data_free_sub.groupby('name')['distance'].max().sort_values(ascending=False).head()
# Out:
# name
# Александр    7211.01
# Светлана     7066.00
# Тамерлан     6908.49
# Роман        6760.94
# Ян           6724.93
# Name: distance, dtype: float64

# %%
# Топ-5 рекордсменов по дистанции с ultra
data_ultra_sub.groupby('name')['distance'].max().sort_values(ascending=False).head()
# Out:
# name
# Ольга      5699.77
# Олег       5419.68
# Виктор     5391.97
# Семен      5371.48
# Алексей    5335.21
# Name: distance, dtype: float64

# %%
# Топ-5 рекордсменов по длительности с free
data_free_sub.groupby('name')['duration'].max().sort_values(ascending=False).head()
# Out:
# name
# Анжелика    34.948498
# Светлана    34.932489
# Дарья       34.909963
# Эльвира     34.888965
# Вероника    34.881139
# Name: duration, dtype: float64

# %%
# Топ-5 рекордсменов по длительности с ultra
data_ultra_sub.groupby('name')['duration'].max().sort_values(ascending=False).head()
# Out:
# name
# Вероника    40.823963
# Эвелина     39.873856
# Эдуард      39.526602
# Мадина      38.352763
# Алия        38.265229
# Name: duration, dtype: float64

# %% [markdown]
# __Итого:__ В целом, можно сказать, что с подпиской free ездят дальше, а с ultra - дольше. Но при этом средние показатели как длительности поездок, так и дистанции почти одинаковы.

# %% [markdown]
# ### Выводы.
#
# 1. В результате объединения получили единый датафрейм, содержащий данные о пользователях, их поездках и применяемых в соответствии с типом подписки тарифах. Для удобства дальнейшего анализа этот датафрейм был разделён на два других по типу подписки.
#
# 2. В целом, можно сказать, что пользователи с подпиской ездят немного дольше. Средние показатели как длительности поездок, так и дистанции почти одинаковы для обеих групп пользователей. При сравнении количества поездок в разных городах заметно, что в Омске и Москве доля пользователей с подпиской больше, чем в других городах.
#
# * Хотя соотношение пользователей с подпиской и без неё 45.6% на 54.4%, соотношение поездок с подпиской и без неё, соответственно 36% на 64%. Значит, пользователи без подписки ездят чаще.
#
# 3. Сравнительные графики __дистанции__ поездок, разделённые по тарифам также демонстрируют "провалы", как и общий график распределения дистанций, описанный в п. 3.3. Но на графиках по типам подписки, заметное снижение количества поездок наблюдается около 1300 м для тарифа free и ещё более заметное снижение около 1900 м для тарифа ultra.
#
# * Сравнительные графики __длительности__ поездок с разными тарифами выглядят более логично: в целом, поездок с free больше, чем с ultra, нет значительных "пиков" и "провалов".
#
# * Кроме того, на графике тарифа free имеется достаточно заметное количество поездок с нулевой дистанцией. Вероятно, это неудачные попытки воспользоваться самокатом (или проблемы с приложением).
#
# 4. Медианные значения __дистанции__ очень близки для обоих типов подписки (3148.64 м/ultra и 3114.65 м/free), при этом максимальные значения заметно различаются (самая дальняя поедка с ultra на 5699 м, с free - на 7211 м).
#
# * Медианное значение __длительности__ поездок с ultra (18.18 мин) чуть выше, чем с free (17.32 мин). Самая длительная поезка с ultra продолжалась 40 мин, с free - 35 мин.

# %% [markdown]
# ## Подсчёт выручки

# %%
full_data['duration'] = np.ceil(full_data['duration'])
full_data.head()
# Out:
#    user_id  name  age    city subscription_type  distance  duration  \
# 0        1  Кира   22  Тюмень             ultra   4409.92      26.0
# 1        1  Кира   22  Тюмень             ultra   2617.59      16.0
# 2        1  Кира   22  Тюмень             ultra    754.16       7.0
# 3        1  Кира   22  Тюмень             ultra   2694.78      19.0
# 4        1  Кира   22  Тюмень             ultra   4028.69      27.0
#
#         date  month  minute_price  start_ride_price  subscription_fee
# 0 2021-01-01      1             6                 0               199
# 1 2021-01-18      1             6                 0               199
# 2 2021-04-20      4             6                 0               199
# 3 2021-08-11      8             6                 0               199
# 4 2021-08-28      8             6                 0               199

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, исправили.</font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Согласно заданию длительность каждой поездки должна быть округлена до целой минуты до суммирования за месяц.</font>

# %% [markdown]
# </font><font color='Blue'><b>Комментарий студента</b></font><br>
# Округлил до суммирования,
#
# но в данном случае задание написано не совсем понятно:
#
# 5.1 Создайте датафрейм с агрегированными данными о поездках...
#
# 5.2 В этот же датафрейм добавьте столбец с помесячной выручкой...Продолжительность каждой поездки в каждой строке исходного датафрейма для подсчёта стоимости округляется до следующего целого числа...
#
# Я под исходным датафреймом понял результат пункта 5.1 - датафрейм с агрегированными данными.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkMagenta'>👉 Почему? Там прямо указано, даже пример кода дан.</font>
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Создание датафрейма с агрегированными данными

# %%
# датафрейм с агрегированными данными

data_agg = full_data.groupby(['user_id', 'month']).agg({'date': 'count', 'distance': 'sum', 'duration': 'sum',
                                                        'minute_price': 'mean', 'start_ride_price': 'mean', 
                                                        'subscription_fee': 'mean'})
data_agg
# Out:
#                date  distance  duration  minute_price  start_ride_price  \
# user_id month
# 1       1         2   7027.51      42.0             6                 0
#         4         1    754.16       7.0             6                 0
#         8         2   6723.47      46.0             6                 0
#         10        2   5809.91      32.0             6                 0
#         11        3   7003.50      56.0             6                 0
# ...             ...       ...       ...           ...               ...
# 1534    6         2   3409.47      26.0             8                50
#         8         2   7622.45      48.0             8                50
#         9         1   4928.17      23.0             8                50
#         11        4  13350.02      78.0             8                50
#         12        1   2371.71      16.0             8                50
#
#                subscription_fee
# user_id month
# 1       1                   199
# ...

# %%
plt.figure()
plt.title('Оценка пропущенных значений')
colours = ['#077336', '#F0F2B3']
sns.heatmap(data_agg.isnull(), cmap=sns.color_palette(colours), alpha=0.5)
# Out:
# <AxesSubplot:title={'center':'Оценка пропущенных значений'}, ylabel='user_id-month'>

# %% [markdown]
# __Итого:__ Датафрейм с агрегированными данными пропусков не имеет.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Перед расчетом выручки необходимо сделать проверку на пропуски в созданной сводной таблице.</font>

# %% [markdown]
# </font><font color='Blue'><b>Комментарий студента</b></font><br>
# Проверил

# %% [markdown]
# ### Добавление помесячной выручки

# %%
# добавление столбца с помесячной выручкой от каждого пользователя
data_agg['income'] = data_agg['start_ride_price'] * data_agg['date'] + data_agg['minute_price'] * data_agg['duration'] + data_agg['subscription_fee']
data_agg
# Out:
#                date  distance  duration  minute_price  start_ride_price  \
# user_id month
# 1       1         2   7027.51      42.0             6                 0
#         4         1    754.16       7.0             6                 0
#         8         2   6723.47      46.0             6                 0
#         10        2   5809.91      32.0             6                 0
#         11        3   7003.50      56.0             6                 0
# ...             ...       ...       ...           ...               ...
# 1534    6         2   3409.47      26.0             8                50
#         8         2   7622.45      48.0             8                50
#         9         1   4928.17      23.0             8                50
#         11        4  13350.02      78.0             8                50
#         12        1   2371.71      16.0             8                50
#
#                subscription_fee  income
# user_id month
# ...

# %%
data_agg['income'].describe()
# Out:
# count    11331.000000
# mean       342.303504
# std        153.875346
# min         58.000000
# 25%        234.000000
# 50%        319.000000
# 75%        415.000000
# max       1444.000000
# Name: income, dtype: float64

# %%
colors = {'0': '#A3D98B', '199': '#F3FAB6'}
data_agg.groupby('subscription_fee')['income'].plot(kind='hist', histtype='step', color=colors,
                                                   linewidth=3,grid=True, legend=True, bins=50, range=(1, 1500))

plt.legend(['Free', 'Ultra'])

plt.title('Общая стоимость поездки в зависимости от типа подписки')
plt.xlabel('Стоимость поездки')
plt.ylabel('Количество поездок*');

# %% [markdown]
# Количество поездок* - агрегированные данные по месяцам.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Неправильно сделан расчет выручки.</font>

# %%
# Комментарий ревьюера
# Контроль суммы выручки
tmp = data_agg.copy()
print("Правильное значение суммы выручки 3878641, сумма выручки расчитанная в таблице:", tmp.income.sum())
# Out:
# Правильное значение суммы выручки 3878641, сумма выручки расчитанная в таблице: 3878641.0

# %% [markdown]
# </font><font color='Blue'><b>Комментарий студента</b></font><br>
# Исправил

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, теперь правильно.</font>

# %% [markdown]
# ### Выводы.
#
# 1. Средняя выручка от одной поездки составляет 340.06 руб, максимальная - 1428.00 руб, но такие поездки - редкость. 75% поездок укладывается в 412.00 руб. Минимальная поездка принесла 58 руб, это как раз стоимость старта + одна минута поездки (на тарифе free).
#
# 2. Графики помесячной выручки от поездок с разными тарифами в некоторой степени повторяют друг друга в начале, но график тарифа ultra "сдвинут" вправо, что объясняется наличием абонентской платы на этом тарифе. Оба "пика" на графиках приблизительно соответствуют средней длительности поездок (17-18 мин).

# %% [markdown]
# ## Проверка гипотез
#
# Продакт-менеджеры сервиса хотят увеличить количество пользователей с подпиской. Для этого они будут проводить различные акции, но сначала нужно выяснить несколько важных моментов.
#
# 6.1 Важно понять, тратят ли пользователи с подпиской больше времени на поездки? Если да, то пользователи с подпиской могут быть «выгоднее» для компании.
#
# 6.2 Расстояние одной поездки в 3130 метров — оптимальное с точки зрения износа самоката. Можно ли сказать, что среднее расстояние, которое проезжают пользователи с подпиской за одну поездку, не превышает 3130 метров?
#
# 6.3 Будет-ли помесячная выручка от пользователей с подпиской по месяцам выше, чем выручка от пользователей без подписки?
#
# 6.4 Моделируемая ситуация: техническая команда сервиса обновила сервера, с которыми взаимодействует мобильное приложение. Она надеется, что из-за этого количество обращений в техподдержку значимо снизилось. Некоторый файл содержит для каждого пользователя данные о количестве обращений до обновления и после него. Какой тест понадобился бы для проверки этой гипотезы?

# %% [markdown]
# ### Проверка гипотезы тратят ли пользователи с подпиской больше времени на поездки?

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Не сформулированы нулевая и альтернативная гипотезы. Заказчик не читает текст в ячейке кода, тем более когда он уходит за размеры экрана. Гипотезы должны быть сформулированы в ячейке Markdown.</font>

# %% [markdown]
# Необходимо проверить гипотезу о том, тратят ли пользователи с подпиской больше времени на поездки?
#
# Проводим тест для двух выборок: пользователей с подпиской и пользователей без подписки.
#
# В качестве нулевой гипотезы принимаем, что средние значения длительности поездок обеих групп равны, в качестве альтернативной - используем одностороннюю гипотезу «больше», т.е. пользователи с подпиской тратят больше времени на поездки.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, правильно сформулированы гипотезы.</font>

# %%
# Тратят ли пользователи с подпиской больше времени на поездки?

import scipy.stats as st
#Выбираем уровень статистической значимости 5%
alpha = 0.05

# длительность поездок пользователей с подпиской
ultra_sub_group = data_ultra_sub['duration']
display(f'Среднее значение времени поездок пользователей с подпиской: {data_ultra_sub.duration.mean().round(2)}')

# длительность поездок пользователей без подписки
free_sub_group = data_free_sub['duration']
display(f'Среднее значение времени поездок пользователей без подписки: {data_free_sub.duration.mean().round(2)}')

results = st.ttest_ind(ultra_sub_group, free_sub_group, equal_var=False, alternative='greater')

display(f'p-value: {results.pvalue}')

# проверяем p-value
if results.pvalue < alpha:
    display('Отвергаем нулевую гипотезу: пользователи с подпиской тратят больше времени на поездки, чем пользователи без подписки')
else:
    display('Нет оснований отвергнуть нулевую гипотезу')
# Out:
# 'Среднее значение времени поездок пользователей с подпиской: 18.54'
# 'Среднее значение времени поездок пользователей без подписки: 17.39'
# 'p-value: 5.6757813771289775e-37'
# 'Отвергаем нулевую гипотезу: пользователи с подпиской тратят больше времени на поездки, чем пользователи без подписки'

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Правильно, что для тестирования гипотез использован t-тест.</font><br>
# <font color='DarkMagenta'>👉 Было бы правильным показать дополнительно средние значения времени поездок пользователей с подпиской и без, как иллюстрации не противоречивости результата тестирования гипотез, используя метод `.mean()` для выборок.</font>

# %% [markdown]
# </font><font color='Blue'><b>Комментарий студента</b></font><br>
# Исправил, добавил.

# %% [markdown]
# Вывод: статистический тест показывает, что пользователи с подпиской ultra тратят в среднем больше времени на поездки, чем пользователи без подписки.

# %% [markdown]
# ### Проверка гипотезы что среднее расстояние, которое проезжают пользователи с подпиской за одну поездку, не превышает 3130 метров

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Не сформулированы нулевая и альтернативная гипотезы.</font>

# %% [markdown]
# Необходимо проверить гипотезу о том, что среднее расстояние, которое проезжают пользователи с подпиской за одну поездку, не превышает 3130 метров. Расстояние одной поездки в 3130 метров — оптимальное с точки зрения износа самоката.
#
# Проводим тест для одной выборки (пользователи с подпиской). Нулевая гипотеза: среднее расстояние меньше или равно 3130 м, альтернативная - среднее расстояние превышает оптимальное.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, сформулированы гипотезы.</font>

# %%
# Среднее расстояние с подпиской не превышает 3130 метров

#Выбираем уровень статистической значимости 5%
alpha = 0.05

# расстояние, которое проезжают пользователи с подпиской
ultra_sub_dist = data_ultra_sub['distance']
display(f'Среднее расстояние, которое проезжают пользователи с подпиской: {data_ultra_sub.distance.mean().round(2)}')

# оптимальное расстояние
interested_dist = 3130

results = st.ttest_1samp(ultra_sub_dist, interested_dist, alternative='greater')

display(f'p-value: {results.pvalue}')

# проверяем p-value
if results.pvalue < alpha:
    display('Отвергаем нулевую гипотезу: среднее расстояние превышает значение в 3130 м')
else:
    display('Нет оснований отвергнуть нулевую гипотезу: среднее расстояние меньше или равно 3130 м')
# Out:
# 'Среднее расстояние, которое проезжают пользователи с подпиской: 3115.45'
# 'p-value: 0.9195362605842414'
# 'Нет оснований отвергнуть нулевую гипотезу: среднее расстояние меньше или равно 3130 м'

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkGreen'>👌 Правильное решение.</font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Не корректно проводится тестирование, не правильное значение `alternative`. </font><br>

# %% [markdown]
# </font><font color='Blue'><b>Комментарий студента</b></font><br>
# Исправил

# %% [markdown]
# Вывод: статистический тест показывает, что среднее расстояние, которое проезжают пользователи с подпиской не превышает оптимальное с точки зрения износа самоката значение в 3130 метров.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Вывод тестирования гипотез необходимо формулировать применительно к запросу бизнеса, что такое дистанция в 3130 метров?</font>

# %% [markdown]
# ### Проверка гипотезы что помесячная выручка от пользователей с подпиской по месяцам выше, чем выручка от пользователей без подписки.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Не сформулированы нулевая и альтернативная гипотезы.</font>

# %% [markdown]
# </font><font color='Blue'><b>Комментарий студента</b></font><br>
# Исправил

# %% [markdown]
# Необходимо проверить гипотезу о том, что помесячная выручка от пользователей с подпиской по месяцам выше, чем выручка от пользователей без подписки.
#
# Проводим тест для двух выборок: пользователей с подпиской и пользователей без подписки.
#
# В качестве нулевой гипотезы принимаем, что средние значения помесячной выручки обеих групп равны, в качестве альтернативной - что пользователи с подпиской приносят бОльшую выручку.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, исправили.</font>

# %%
# Выручка от пользователей с подпиской выше, чем выручка от пользователей без подписки.
#Выбираем уровень статистической значимости 5%
alpha = 0.05

# помесячная выручка с ultra
ultra_sub_income = data_agg.query('start_ride_price == 0')['income']
display(f'Среднее значение помесячной выручки от пользователей с подпиской: {ultra_sub_income.mean().round(2)}')

# помесячная выручка с free
free_sub_income = data_agg.query('start_ride_price != 0')['income']
display(f'Среднее значение помесячной выручки от пользователей без подписки: {free_sub_income.mean().round(2)}')

results = st.ttest_ind(ultra_sub_income, free_sub_income, equal_var=False, alternative='greater')

display(f'p-value: {results.pvalue}')

# проверяем p-value
if results.pvalue < alpha:
    display('Отвергаем нулевую гипотезу: пользователи с подпиской приносят бОльшую выручку.')
else:
    display('Нет оснований отвергнуть нулевую гипотезу: средние значения помесячной выручки обеих групп равны')
# Out:
# 'Среднее значение помесячной выручки от пользователей с подпиской: 362.79'
# 'Среднее значение помесячной выручки от пользователей без подписки: 328.64'
# 'p-value: 8.874140893976874e-40'
# 'Отвергаем нулевую гипотезу: пользователи с подпиской приносят бОльшую выручку.'

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Правильно проведено тестирование гипотез.</font>

# %% [markdown]
# Вывод: результаты теста показывают, что помесячная выручка от пользователей с подпиской по месяцам выше, чем выручка от пользователей без подписки.

# %% [markdown]
# ### Проверка гипотезы об уменьшении количества обращений в тех. поддержку

# %% [markdown]
# Для проверки гипотезы об уменьшении количества обращений в тех.поддержку применим метод `scipy.stats.ttest_rel()`
#
# например:
#
# results = st.ttest_rel(tickets_before, tickets_after, alternative='greater'),
#
# где tickets_before и tickets_after - данные об обращении пользователей в тех. поддержку до обновления и после него.
#
# В качестве основной гипотезы примем равенство количества обращений до и после обновления, в качестве альтернативной - уменьшение количества обращений после обновления.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Все правильно, только не указано какой параметр `aternative` будем использовать при тестировании.</font>

# %% [markdown]
# </font><font color='Blue'><b>Комментарий студента</b></font><br>
# Добавил

# %% [markdown]
# ### Выводы.
#
# Статистические тесты показали, что:
#
# * пользователи с подпиской тратят в среднем больше времени на поездки, чем пользователи без подписки, а значит, они могут быть «выгоднее» для компании;
#
# * среднее расстояние, которое проезжают пользователи с подпиской не превышает значение в 3130 метров (оптимальное с точки зрения износа самокатов);
#
# * помесячная выручка от пользователей с подпиской по месяцам выше, чем выручка от пользователей без подписки (хотя пользователи без подписки ездят активнее);
#
# * Увеличение пользователей с подпиской, в целом, может способствовать увеличению выручки.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Жалко, что не стали делать необязательные задания.</font>

# %% [markdown]
# </font><font color='Blue'><b>Комментарий студента</b></font><br>
# Попробовал сделать необязательные задания, но не чувствую себя уверенно в этой теме.

# %% [markdown]
# ## Распределения

# %% [markdown]
# ### Акция с раздачей промокодов.
#
# Отделу маркетинга GoFast поставили задачу: нужно провести акцию с раздачей промокодов на один бесплатный месяц подписки, в рамках которой как минимум 100 существующих клиентов должны продлить эту подписку. То есть по завершении периода действия подписки пользователь может либо отказаться от неё, либо продлить, совершив соответствующий платёж.
#
# Эта акция уже проводилась ранее и по итогу выяснилось, что после бесплатного пробного периода подписку продлевают
# 10 % пользователей.
#
# Необходимо выяснить, какое минимальное количество промокодов нужно разослать, чтобы вероятность не выполнить план была примерно 5 %.
#
# Нужно подобрать параметры распределения, описывающего эту ситуацию, построить график распределения и сформулировать ответ на вопрос о количестве промокодов.

# %%
from math import sqrt
from scipy import stats as st

n = 1168 # min количество промокодов
p = 0.1 # вероятность продления подписки

# параметры нормального распределения
mu = n * p
sigma = sqrt(n * p * (1 - p))

distr = st.norm(mu, sigma) # функция нормального распределения

result = distr.cdf(100) # вероятность невыполнения плана по продлению подписки (д.б. около 5%)
result
# Out:
# 0.050650790692463

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkMagenta'>👉 А откуда взяли число 1168?<br>А расчитывается оно вот так:</font>
# ![image.png](attachment:image.png)

# %%
from matplotlib import pyplot as plt
from scipy.stats import binom

n = 1168 # количество промокодов
p = 0.1 # вероятность продления подписки

distr = []

# функция биномиального распределения
for k in range(0, n + 1):
    current_value = binom.pmf(k, n, p)
    distr.append(current_value)
# график аппроксимированного нормальными распределения
plt.bar(range(0, n + 1), distr)
# Out:
# /opt/conda/lib/python3.9/site-packages/scipy/stats/_discrete_distns.py:78: RuntimeWarning: divide by zero encountered in _binom_pdf
#   return _boost._binom_pdf(x, n, p)
# <BarContainer object of 1169 artists>

# %% [markdown]
# __ИТОГО:__ 1168 - это минимальное количество промокодов, которые нужно разослать, чтобы с 95% вероятностью получить 100 продлений подписки в рамках акции (или с 5% вероятностью не получить эти 100 продлений).

# %% [markdown]
# ### Рассылка push-уведомлений
#
# Отдел маркетинга рассылает клиентам push-уведомления в мобильном приложении. Клиенты могут открыть его или не открывать. Известно, что уведомления открывают около 40 % получивших клиентов. Отдел планирует разослать 1 млн уведомлений.
#
# С помощью аппроксимации постройте примерный график распределения и оцените вероятность того, что уведомление откроют не более 399,5 тыс. пользователей.

# %%
from math import sqrt
from scipy import stats as st

n = 1000000 # количество рассылаемых уведомлений
p = 0.4 # вероятность открытия уведомления пользователем

# параметры нормального распределения
mu = n * p
sigma = sqrt(n * p * (1 - p))

# функция нормального распределения
distr = st.norm(mu, sigma)

# считаем вероятность хвоста слева от 399,5 тыс
result = distr.cdf(399500)
result
# Out:
# 0.15371708296369768

# %% [markdown]
# __ИТОГО:__ При рассылке пользователям сервиса 1 млн push-уведомлений в мобильном приложении вероятность того, что уведомление откроют не более 399,5 тыс. пользователей равна 15.4%.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkGreen'>👌 Молодец, справились с необязательным заданием.</font>

# %% [markdown]
# ## Общие выводы
#
# __Исходные данные__
#
# Данные для анализа получены из трех датасетов, полученных от сервиса проката самокатов GoFast. Датасеты содержат информацию о пользователях сервиса, их подписках и поездках в период с 01 января по 30 декабря 2021 года. В данных имеются имя пользователя и его ID, город и возраст, тип подписки, время, проведенное в поездке и расстояние поздки. Кроме того, один из датасетов содержит финансовые данные о тарифах для пользователей с подпиской и без.
#
# - Общий обзор данных показал отсутствие пропусков в данных, что здорово облегчает дальнейшую обработку и говорит о хорошей подготовке данных. Все наборы данных соответствуют описанию. Типы данных соответствуют параметру, за исключением параметра даты, имеющего тип object.
#
# __Предобработка__
#
# - В процессе предобработки тип данных параметра даты был изменен на `datetime64[ns]`, был выделен отдельный столбец с номером месяца, необходимый для дальнейшего анализа и удалены дубликаты.
#
# - Кроме того, проверка параметра длительности показала, что поездки длительностью менее 2 и более 35 минут выглядят аномальными, хотя возможен сценарий, при котором сверхкороткие поездки (менее 2 мин)  - это результат неисправности самоката или неполадок с приложением.
#
# __Исследовательский анализ__
#
# 1. В результате предварительного анализа выявились следующие особенности представленных данных:
#
# - Больше всего пользователей сервиса проживает в Пятигорске и меньше всего - в Москве. Возможно, это особенность выборки, или сервис действительно более популярен в регионах.
#
# - Пользователи с подпиской составляют почти половину: 45.6%.
#
# - Возраст пользователей варьируется от 12 до 43 лет, средний возраст - 25 лет. (В датасете минимальный возраст пользователей 12 лет, но это похоже на нарушение существующих норм, поскольку прокат самокатов разрешен с 18 лет, в некоторых регионах - с 14 лет.)
#
# - Средняя дистанция одной поездки - чуть больше 3000 м, максимальная - 7211 м (достаточно много для самоката). 75% поездок укладываются в 3800 м.
#
# - Средняя длительность одной поездки - менее 18 мин. Максимальная длительность поездки - более 40 минут. 75% поездок укладываются в 22 мин.
#
# 2. Датасеты были преобразованы в единый датафрейм, объединяющий данные о всех пользователях и разделенный затем на два датасета по принципу наличия у пользователя подписки. В результате дальнейшего анализа выявились некоторые различия в поведении пользователей с подпиской и без нее:
#
# - Несмотря на то, что пользователи с подпиской составляют почти половину всех пользователей сервиса, они совершают лишь 36% всех поездок. Но, вместе с тем, выяснилось, что пользователи с подпиской тратят в среднем больше времени на поездки и, поскольку оплата пользования самокатом зависит от времени поездки, в итоге, они приносят бОльший доход сервису, чем пользователи без подписки.
#
# - Среднее время поездки и среднее расстояние не сильно отличаются в обеих категориях пользователей, но у пользователей с подпиской оба показателя чуть больше.
#
# - При анализе графиков распределения поездок по расстоянию (пункт 4.3) выявилось заметное снижение количества поездок на растояние около 1300 м для тарифа free и ещё более заметное снижение около 1900 м для тарифа ultra. Была версия, что это снижение как-то связано со средним расстоянием между остановками общественного транспорта, где расположены парковки самокатов. Но на графиках распределения поздок по времени подобного снижения количества поездок не наблюдается.
#
# 3. Далее данные были сагрегированы для вычисления помесячной выручки от каждого клиента. Среднее значение выручки составило 340.06 руб, максимальное - 1428.00 руб. 75% поездок укладывается в 412.00 руб.
#
# __Проверка гипотез__
#
# При помощи статистических тестов были проверены некоторые гипотезы, которые могут помочь в развитии сервиса. Тестами было подтверждено, что:
#
# - пользователи с подпиской тратят больше времени на поездки, чем пользователи без подписки;
#
# - среднее расстояние, которое проезжают пользователи с подпиской за одну поездку, не превышает 3130 метров (оптимальное расстояние с точки зрения износа самоката);
#
# - помесячная выручка от пользователей с подпиской по месяцам выше, чем выручка от пользователей без подписки.
#
# Все это дает основание предположить, что увеличение количества пользователей с подпиской может способствовать увеличению выручки.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Общий вывод относится ко всему проекту.<br>Он должен содержать развернутое резюме по всем разделам проекта: описание предобработка данных и все этапы исследовательского и статистического анализа.</font>

# %% [markdown]
# </font><font color='Blue'><b>Комментарий студента</b></font><br>
# Переписал общий вывод

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkMagenta'>👉 Общий вывод проекта должен содержать следующие основные моменты:<br>
# - Краткое описание целей и задач проекта.<br>
# - Основные результаты, полученные в ходе выполнения проекта.<br>
# - Анализ всех разделов проекта, включая раздел анализа и предобработки данных, и их влияния на общие результаты.<br>
# - Возможные направления дальнейшего развития и применения полученных результатов.<br>
# Общий вывод должен быть написан в логической последовательности и отражать общую картину проекта. Он должен быть кратким, но содержательным, чтобы заказчик мог получить полное представление о проекте и его значимости.</font>

# %% [markdown]
# <font color='DarkBlue'><b>Заключительный комментарий ревьюера 00</b></font><br>
# <font color='DarkGreen'>👌 Сергей!<br></font>
# <font color='Red'>🛠 Увы, должен прервать ревью из-за ошибки в коде. Настоятельно рекомендую перед отправкой проекта на ревью проверять в JupyterHub исполнение кода тетрадки (см.скрин ниже).<br>
# Необходимо исправить ошибки, в том числе уже обнаруженные:<br>
# Графики и диаграммы необходимо оформить подписями осей и названием графика/диаграммы на русском языке. Необходимо вывести числовые количества пользователей в городах. Проверить размерности датасета после объединения и проверить пропуски объединенного датасета.<br>
# Жду исправленный проект. Если будут трудности, можно обратиться к куратору. </font>
# ![image.png](attachment:image.png)

# %% [markdown]
# <font color='DarkBlue'><b>Заключительный комментарий ревьюера</b></font><br><br>
# <font color='DarkGreen'>👌 Сергей, проект очень хорошо и детально проработан. И дальше так держать!<br></font>
# <font color='Red'>🛠 Что бы еще лучше сделать проект надо:</font><br>
# <font color='Red'>🛠 Графики и диаграммы необходимо оформить подписями осей и названием графика/диаграммы на русском языке. Сделать округление длительность каждой поездки до целой минуты перед суммированием длительности за месяц. Сделать проверку на пропуски в сводной таблице до расчета выручки. Переделать расчет выручки. Сформулировать гипотезы по продолжительности поездок пользователями с подпиской. Правильно сформулировать гипотезы по среднему расстоянию проезжающему пользователями с подпиской. Переделать задание по тестированию гипотез по среднему расстоянию проезжающему пользователями с подпиской. Сформулировать расширенный общий вывод проекта. <br></font>
# <font color='DarkMagenta'>👉 При исправлении ошибок и недочетов приобретем дополнительный опыт и навыки!</font><br>
# <font color='DarkGreen'>👌 Жду окончательный вариант! Удачи. </font>

# %% [markdown]
# <font color='DarkBlue'><b>Заключительный комментарий ревьюера 2</b></font><br><br>
# <font color='DarkGreen'>👌 Сергей! Удалось справиться со всеми заданиями в проекте. Молодец! 😄 Спасибо за работу!<br>
# Входе выполнения проекта научились анализировать первичные данные, проводить обработку датасета, объединять таблицы. Провели самостоятельный исследовательский и статистический анализ. </font><br>
# <font color='DarkGreen'>👌 Теперь, вперед за новыми знаниями и навыками! Удачи! 😉</font>
# ![image.png](attachment:image.png)
